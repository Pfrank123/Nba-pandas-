# %%
import pandas as pd
df = pd.DataFrame({'categories': [34.7, 5.1, 4.8],
                   'radius': [2439.7, 6051.8, 6378.1]},
                  index=['PPG', 'RPG', 'APG'])
plot = df.plot.pie(y='categories', figsize=(20, 15))
